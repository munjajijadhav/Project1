# %%
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load & Read the data

# %%
df = pd.read_csv('C:\\Users\\Munjaji\\Desktop\\Python program\\Marsian Tech Notes\\Projects Data Analytics For Students\\Projects Data Analytics For Students\\Project 1\\pupae.csv')

# %%
df.head()
# Out:
#   T_treatment  CO2_treatment  Gender  PupalWeight  Frass
# 0     ambient            280     0.0        0.244  1.900
# 1     ambient            280     1.0        0.319  2.770
# 2     ambient            280     0.0        0.221    NaN
# 3     ambient            280     0.0        0.280  1.996
# 4     ambient            280     0.0        0.257  1.069

# %%
df.tail()
# Out:
#    T_treatment  CO2_treatment  Gender  PupalWeight  Frass
# 79    elevated            400     0.0        0.314  1.885
# 80    elevated            400     0.0        0.294  1.993
# 81    elevated            400     0.0        0.254  1.907
# 82    elevated            400     0.0        0.225  1.516
# 83    elevated            400     0.0        0.331  1.962

# %%
df.describe()
# Out:
#        CO2_treatment     Gender  PupalWeight      Frass
# count      84.000000  78.000000    84.000000  83.000000
# mean      344.285714   0.448718     0.311024   1.846446
# std        60.206186   0.500582     0.064140   0.429909
# min       280.000000   0.000000     0.172000   0.986000
# 25%       280.000000   0.000000     0.256250   1.515000
# 50%       400.000000   0.000000     0.297500   1.818000
# 75%       400.000000   1.000000     0.356000   2.095500
# max       400.000000   1.000000     0.473000   3.117000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   T_treatment    84 non-null     object
#  1   CO2_treatment  84 non-null     int64
#  2   Gender         78 non-null     float64
#  3   PupalWeight    84 non-null     float64
#  4   Frass          83 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.4+ KB

# %%
df.shape
# Out:
# (84, 5)

# %%
df.nunique()
# Out:
# T_treatment       2
# CO2_treatment     2
# Gender            2
# PupalWeight      70
# Frass            80
# dtype: int64

# %%
# Findout missing values in data

# %%
df.isnull().sum()
# Out:
# T_treatment      0
# CO2_treatment    0
# Gender           6
# PupalWeight      0
# Frass            1
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df['Gender'].value_counts()
# Out:
# 0.0    43
# 1.0    35
# Name: Gender, dtype: int64

# %%
# Replace missing value with mode in Gender
df['Gender'].mode()[0]
# Out:
# 0.0

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# T_treatment      0
# CO2_treatment    0
# Gender           0
# PupalWeight      0
# Frass            1
# dtype: int64

# %%
df['Frass'].unique()
# Out:
# array([1.9  , 2.77 ,   nan, 1.996, 1.069, 2.257, 2.198, 1.873, 2.22 ,
#        1.807, 1.877, 1.488, 2.033, 1.913, 1.665, 1.793, 1.818, 2.672,
#        2.168, 2.603, 2.096, 2.536, 2.172, 1.886, 3.117, 1.735, 1.919,
#        1.553, 2.631, 2.095, 1.965, 1.893, 2.121, 1.657, 1.739, 2.747,
#        1.617, 1.636, 1.513, 1.385, 1.806, 1.444, 1.22 , 1.501, 1.765,
#        1.411, 1.282, 1.358, 1.093, 1.369, 1.826, 1.388, 0.986, 1.414,
#        1.632, 1.378, 1.638, 1.791, 1.676, 1.068, 2.098, 1.45 , 1.514,
#        2.587, 1.511, 2.347, 1.612, 1.959, 2.567, 1.367, 1.842, 2.279,
#        1.902, 1.746, 1.687, 2.461, 1.885, 1.993, 1.907, 1.516, 1.962])

# %%
df['Frass'].value_counts()
# Out:
# 2.220    2
# 1.873    2
# 1.791    2
# 1.893    1
# 2.631    1
#         ..
# 1.068    1
# 2.347    1
# 2.257    1
# 1.444    1
# 1.739    1
# Name: Frass, Length: 80, dtype: int64

# %%
# Replace missing value with mean in Frass
df['Frass'].mean()
# Out:
# 1.84644578313253

# %%
df['Frass']=df['Frass'].fillna(df['Frass'].mean())

# %%
df['Frass'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()  # No missing Value In the data
# Out:
# T_treatment      0
# CO2_treatment    0
# Gender           0
# PupalWeight      0
# Frass            0
# dtype: int64

# %%
df.head()
# Out:
#   T_treatment  CO2_treatment  Gender  PupalWeight     Frass
# 0     ambient            280     0.0        0.244  1.900000
# 1     ambient            280     1.0        0.319  2.770000
# 2     ambient            280     0.0        0.221  1.846446
# 3     ambient            280     0.0        0.280  1.996000
# 4     ambient            280     0.0        0.257  1.069000

# %%
#Query 02:  Convert ’CO2_treatment’ to a factor/categorical discrete variable. Inspect the levels of this factor vriable

# %%
df['CO2_treatment'].unique()
# Out:
# array([280, 400], dtype=int64)

# %%
##pd.get_dummies(df['CO2_treatment'],drop_first=False, axis=1)

# %%
df['CO2_treatment'] = df['CO2_treatment'].map({280:1,400:2})

# %%
df.head()
# Out:
#   T_treatment  CO2_treatment  Gender  PupalWeight     Frass
# 0     ambient              1     0.0        0.244  1.900000
# 1     ambient              1     1.0        0.319  2.770000
# 2     ambient              1     0.0        0.221  1.846446
# 3     ambient              1     0.0        0.280  1.996000
# 4     ambient              1     0.0        0.257  1.069000

# %%
df.tail()
# Out:
#    T_treatment  CO2_treatment  Gender  PupalWeight  Frass
# 79    elevated              2     0.0        0.314  1.885
# 80    elevated              2     0.0        0.294  1.993
# 81    elevated              2     0.0        0.254  1.907
# 82    elevated              2     0.0        0.225  1.516
# 83    elevated              2     0.0        0.331  1.962

# %%
# Query 03 : Make a scatter plot of Frass vs. PupalWeight, with blue solid circles for a CO2 concentration of 
#280ppm and red for 400ppm. Also add a legend.

# %%
plt.figure(figsize=(5,4), dpi=500)
plt.scatter(df['PupalWeight'], df['Frass'], df.CO2_treatment==1,label='280ppm', c='b')
plt.scatter(df['PupalWeight'], df['Frass'], df.CO2_treatment==2,label='400ppm', c='r')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs Frass')
plt.legend()

# %%
#Query 4 : The problem with the above figure is that data for both temperature treatments is combined.Make two plots 
#(either in a PDF, or two plots side by side), one with the ’ambient’ temperature treatment, one with ’elevated’.

# %%
plt.figure(figsize=(5,4), dpi=500)
plt.scatter(df[df.T_treatment=='ambient'].PupalWeight, df[df.T_treatment=='ambient'].Frass, df[df.T_treatment=='ambient'].CO2_treatment==1,label='280ppm', c='b')
plt.scatter(df[df.T_treatment=='ambient'].PupalWeight, df[df.T_treatment=='ambient'].Frass, df[df.T_treatment=='ambient'].CO2_treatment==2,label='400ppm', c='r')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs Frass for ambient Temerature (CO2_treatment)')
plt.legend()

plt.figure(figsize=(5,4), dpi=500)
plt.scatter(df[df.T_treatment=='elevated'].PupalWeight, df[df.T_treatment=='elevated'].Frass, df[df.T_treatment=='elevated'].CO2_treatment==1,label='280ppm', c='b')
plt.scatter(df[df.T_treatment=='elevated'].PupalWeight, df[df.T_treatment=='elevated'].Frass, df[df.T_treatment=='elevated'].CO2_treatment==2,label='400ppm', c='r')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs Frass for elevated Temerature (CO2_treatment)')
plt.legend()
## plt.savefig('path')

# %%
# # 2nd Way

# %%
# plt.figure(figsize=(8,6),)
# df_280 = df[df.CO2_treatment==1]
# df_400 = df[df.CO2_treatment==2]
# plt.scatter(df_280.PupalWeight,df_280.Frass,s=50, label='280ppm', c='b')
# plt.scatter(df_400.PupalWeight,df_400.Frass,s=50, label='400ppm', c='r')
# plt.xlabel('PupalWeight')
# plt.ylabel('Frass')
# plt.title('PupalWeight Vs Frass')
# plt.legend()

# %%
## Query5: In the above plot, make sure that the X and Y axis ranges are the same for both plots.

# %%
plt.figure(figsize=(5,4), dpi=500)
plt.scatter(df[df.T_treatment=='ambient'].PupalWeight, df[df.T_treatment=='ambient'].Frass, df[df.T_treatment=='ambient'].CO2_treatment==1,label='280ppm', c='b')
plt.scatter(df[df.T_treatment=='ambient'].PupalWeight, df[df.T_treatment=='ambient'].Frass, df[df.T_treatment=='ambient'].CO2_treatment==2,label='400ppm', c='r')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs Frass for ambient Temerature (CO2_treatment)')
plt.legend()
axis = plt.gca()
axis.set_xlim([0.15,0.5])
axis.set_ylim([1,3.25])

plt.figure(figsize=(5,4), dpi=500)
plt.scatter(df[df.T_treatment=='elevated'].PupalWeight, df[df.T_treatment=='elevated'].Frass, df[df.T_treatment=='elevated'].CO2_treatment==1,label='280ppm', c='b')
plt.scatter(df[df.T_treatment=='elevated'].PupalWeight, df[df.T_treatment=='elevated'].Frass, df[df.T_treatment=='elevated'].CO2_treatment==2,label='400ppm', c='r')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs Frass for elevated Temerature (CO2_treatment)')
plt.legend()

axis = plt.gca()
axis.set_xlim([0.15,0.5])
axis.set_ylim([1,3.25])

## plt.savefig('path')
# Out:
# (1.0, 3.25)

# %% [markdown]
# ### Query 6 :
# Instead of making two separate plots, make one plot that uses different colors for the CO(2)
# treatments and different symbols for the ’ambient’ and ’elevated’ temperature treatments.
# Choose some nice symbols from the help page of the points function.

# %%
plt.plot(df[df.T_treatment=='ambient'].PupalWeight, df[df.T_treatment=='ambient'].Frass, df[df.T_treatment=='ambient'].CO2_treatment==1,linestyle=' ',marker='s',markersize=6,markerfacecolor='b',label='280ppm')
plt.plot(df[df.T_treatment=='ambient'].PupalWeight, df[df.T_treatment=='ambient'].Frass, df[df.T_treatment=='ambient'].CO2_treatment==2,linestyle=' ',marker='o',markersize=6,markerfacecolor='r',label='400ppm')
plt.plot(df[df.T_treatment=='elevated'].PupalWeight, df[df.T_treatment=='elevated'].Frass, df[df.T_treatment=='elevated'].CO2_treatment==1,linestyle=' ',marker='D',markersize=6,markerfacecolor='g',label='280ppm', c='b')
plt.plot(df[df.T_treatment=='elevated'].PupalWeight, df[df.T_treatment=='elevated'].Frass, df[df.T_treatment=='elevated'].CO2_treatment==2,linestyle=' ',marker='*',markersize=6,markerfacecolor='r',label='400ppm', c='r')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs Frass')
plt.legend()

axis = plt.gca()
axis.set_xlim([0.15,0.5])
axis.set_ylim([1,3.25])
# Out:
# (1.0, 3.25)

# %%
df_a = df[df.T_treatment=='ambient']
df_e = df[df.T_treatment=='elevated']

df_400 = df[df.CO2_treatment==2]
df_280 = df[df.CO2_treatment==1]

plt.plot(df_280.PupalWeight, df_280.Frass, marker='o', linestyle=' ', label='280ppm', c='b')
plt.plot(df_400.PupalWeight, df_400.Frass, marker='o', linestyle=' ', label='400ppm', c='r')
plt.plot(df_a.PupalWeight,df_a.Frass, marker='+',  linestyle=' ', label='ambient')
plt.plot(df_e.PupalWeight,df_e.Frass, marker='*',  linestyle=' ',label='elevated')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs.Frass')
plt.legend()
axis = plt.gca()
axis.set_xlim([0.15,0.5])
axis.set_ylim([1,3.25])
# Out:
# (1.0, 3.25)

# %% [markdown]
# ## Query 7 :
# Add two legends to the above plot, one for the temperature treatment (showing different
# plotting symbols), and one for the CO2 treatments (showing different colours).

# %%
df_a = df[df.T_treatment=='ambient']
df_e = df[df.T_treatment=='elevated']

df_400 = df[df.CO2_treatment==2]
df_280 = df[df.CO2_treatment==1]

plt.plot(df_280.PupalWeight, df_280.Frass, marker='o', linestyle=' ', label='280ppm', c='b')
plt.plot(df_400.PupalWeight, df_400.Frass, marker='o', linestyle=' ', label='400ppm', c='r')
plt.plot(df_a.PupalWeight,df_a.Frass, marker='+',  linestyle=' ', label='ambient', c='g')
plt.plot(df_e.PupalWeight,df_e.Frass, marker='*',  linestyle=' ',label='elevated',c='y')
plt.xlabel('PupalWeight')
plt.ylabel('Frass')
plt.title('PupalWeight Vs.Frass')
legend1 = plt.legend(['280ppm','400ppm'], loc=2)
axis = plt.gca().add_artist(legend1)
legend2 = plt.legend(['ambient','elevated'], loc=4)

# %% [markdown]
# # Query 8
# #Generate the same plot as above but this time add a single legend that contains symbols and
# colours for each treatment combination (CO2 : T).
